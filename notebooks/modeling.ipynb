# %% [markdown]
# ## Model building

# %%
import sys
import os
import warnings
warnings.filterwarnings('ignore')
sys.path.append('../scripts')
from data_loader import *
from modeling import *

# %%
path1 = os.path.join('..', 'data/processed', 'brent_oil_price.parquet')
brent_oil_df = load_data(path1)
brent_oil_df.set_index('Date', inplace=True)

# %% [markdown]
# ## ARIMA model to the Brent oil prices data

# %%
brent_oil_arima_forecast(brent_oil_df)
# Out:
# C:\Users\Administrator\Downloads\10-Academy\week-10\AiML-brent-oil-price-analysis\myenv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Administrator\Downloads\10-Academy\week-10\AiML-brent-oil-price-analysis\myenv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Administrator\Downloads\10-Academy\week-10\AiML-brent-oil-price-analysis\myenv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# AIC: 29094.40934440073
# ...
